# %%
from UserAgent import UserAgent
import random
import time


class MyAgent(UserAgent):
    def __init__(self):
        super(MyAgent, self).__init__()
        self.target_location = [] # these will be filled in
        self.starting_location = [] # these will be filled in
        self.name = "YOUR NAME HERE"  # keep this and put your own name

        # TODO: Initialize any variables you'll need here!
        self.history = []

    def take_action(self, position, world_info):
        # TODO: replace the code below with your own!

        
        # print(world_info[0]) # 3x3 square beneath our feet
        # print(world_info[1]) # 3x3 square 1 block above our feet
        # print(world_info[2]) # 3x3 square 2 blocks above our feet

        # print(world_info[0][0], world_info[1][0], world_info[2][0]) # type of blocks in front of us
        # print(world_info[0][2], world_info[1][2], world_info[2][2]) # type of blocks behind us
        
        # print(position) # our position in the map
        self.history.append(position)

        # select the next action
        rnd = random.random()
        
        a = random.randint(0, len(self.actions) - 1) # actions are to move north, south, east, west ...for now
        action = self.actions[a]

        # if the two blocks in front of us are stone, randomly choose another action
        while (action == "north" and (world_info[1][0][1] == "stone" or world_info[2][0][1] == "stone")):  
            a = random.randint(0, len(self.actions) - 1)
            action = self.actions[a]

        position_change = self.position_change(action)
        next_position = [position[i] + position_change[i] for i in range(len(position))]
        print("next pos:", next_position)
        print("Random action: %s" % action)

        # try to send the selected action
        self.move_direction(action)

# %%
# Run to submit your code. Don't modify this!
if __name__ == "__main__":
    import subprocess
    import time
    
    subprocess.check_output(["jupyter", "nbconvert", "--to", "script", "solution.ipynb"])
    print("done")
    time.sleep(2)
    print("running here")
    temp = subprocess.check_output(["python", "../mission_server.py", "mission0"]).decode("utf-8").replace('\\\r\\\n', '\r\n')
    print(temp)
# Out:
# done
# running here
# <module 'mission0' from 'C:\\Users\\brian\\Documents\\GitHub\\AlgoCraft\\missions\\mission0\\__init__.py'>
# Loading mission from ../missionfiles/mission0.xml.
# Done loading mission file.
# Waiting for the mission to start ................................ mission started
# next pos: [0, 4, 1]
# Random action: east
# next pos: [-1, 4, -1]
# Random action: north
# next pos: [0, 4, 0]
# Random action: east
# next pos: [-1, 4, 0]
# Random action: south
# next pos: [-1, 4, -3]
# Random action: north
# next pos: [-1, 4, -1]
# Random action: south
# next pos: [-1, 4, -3]
# Random action: south
# next pos: [0, 4, -5]
# Random action: east
# next pos: [-2, 4, -6]
# Random action: west
# next pos: [0, 4, -7]
# Random action: east
# next pos: [-1, 4, -6]
# Random action: south
# next pos: [-2, 4, -8]
# Random action: west
# next pos: [0, 4, -10]
# Random action: east
# next pos: [-1, 4, -12]
# Random action: north
# next pos: [-1, 4, -11]
# Random action: south
# next pos: [-1, 4, -14]
# Random action: north
# next pos: [-1, 4, -13]
# Random action: south
# next pos: [0, 4, -14]
# Random action: east
# next pos: [-1, 4, -16]
# Random action: north
# next pos: [-1, 4, -15]
# Random action: south
# next pos: [0, 4, -17]
# Random action: east
# next pos: [-1, 4, -20]
# Random action: north
# next pos: [-1, 4, -19]
# Random action: south
# next pos: [-1, 4, -22]
# Random action: north
# next pos: [-1, 4, -21]
# Random action: south
# next pos: [-1, 4, -24]
# Random action: north
# next pos: [-2, 4, -24]
# Random action: west
# next pos: [0, 4, -25]
# Random action: east
# next pos: [-1, 4, -24]
# Random action: south
# next pos: [-2, 4, -27]
# Random action: west
# next pos: [-1, 4, -27]
# Random action: south
# next pos: [-1, 4, -29]
# Random action: north
# next pos: [0, 4, -30]
# Random action: east
# next pos: [-1, 4, -29]
# Random action: south
# next pos: [-2, 4, -32]
# Random action: west
# next pos: [-1, 4, -32]
# Random action: south
# next pos: [-2, 4, -34]
# Random action: west
# next pos: [0, 4, -35]
# Random action: east
# next pos: [0, 4, -36]
# Random action: east
# next pos: [-1, 4, -36]
# Random action: south
# next pos: [-1, 4, -36]
# Random action: south
# next pos: [-1, 4, -38]
# Random action: south
# next pos: [-1, 4, -39]
# Random action: south
# next pos: [0, 4, -41]
# Random action: east
# next pos: [0, 4, -42]
# Random action: east
# next pos: [-1, 4, -42]
# Random action: south
# next pos: [-2, 4, -44]
# Random action: west
# next pos: [-2, 4, -45]
# Random action: west
# next pos: [-1, 4, -45]
# Random action: south
# next pos: [0, 4, -47]
# Random action: east
# next pos: [0, 4, -47]
# Random action: east
# next pos: [-2, 4, -49]
# Random action: west
# next pos: [-1, 4, -51]
# Random action: north
# next pos: [-1, 4, -51]
# Random action: north
# next pos: [0, 4, -51]
# Random action: east
# next pos: [-2, 4, -53]
# Random action: west
# next pos: [-1, 4, -53]
# Random action: south
# next pos: [0, 4, -55]
# Random action: east
# next pos: [-1, 4, -55]
# Random action: south
# next pos: [0, 4, -57]
# Random action: east
# next pos: [-1, 4, -56]
# Random action: south
# next pos: [-2, 4, -57]
# Random action: west
# next pos: [-1, 4, -60]
# Random action: north
# next pos: [-1, 4, -59]
# Random action: south
# next pos: [-1, 4, -61]
# Random action: south
# next pos: [0, 4, -63]
# Random action: east
# next pos: [-1, 4, -63]
# Random action: south
# next pos: [0, 4, -65]
# Random action: east
# next pos: [-1, 4, -67]
# Random action: north
# next pos: [-2, 4, -67]
# Random action: west
# next pos: [0, 4, -68]
# Random action: east
# next pos: [-1, 4, -70]
# Random action: north
# next pos: [0, 4, -70]
# Random action: east
# next pos: [0, 4, -70]
# Random action: east
# next pos: [-2, 4, -72]
# Random action: west
# next pos: [0, 4, -73]
# Random action: east
# next pos: [0, 4, -74]
# Random action: east
# next pos: [0, 4, -75]
# Random action: east
# next pos: [-1, 4, -77]
# Random action: north
# next pos: [0, 4, -77]
# Random action: east
# next pos: [-1, 4, -77]
# Random action: south
# next pos: [-2, 4, -79]
# Random action: west
# next pos: [-1, 4, -81]
# Random action: north
# next pos: [-1, 4, -80]
# Random action: south
# next pos: [-1, 4, -83]
# Random action: north
# next pos: [-1, 4, -82]
# Random action: south
# next pos: [0, 4, -84]
# Random action: east
# next pos: [-1, 4, -86]
# Random action: north
# next pos: [-1, 4, -87]
# Random action: north
# next pos: [-1, 4, -88]
# Random action: north
# next pos: [0, 4, -88]
# Random action: east
# next pos: [-1, 4, -88]
# Random action: south
# next pos: [-1, 4, -91]
# Random action: north
# next pos: [-1, 4, -92]
# Random action: north
# next pos: [-1, 4, -93]
# Random action: north
# next pos: [0, 4, -93]
# Random action: east
# next pos: [-1, 4, -95]
# Random action: north
# next pos: [-2, 4, -95]
# Random action: west
# next pos: [0, 4, -96]
# Random action: east
# next pos: [-1, 4, -96]
# Random action: south
# next pos: [-1, 4, -97]
# Random action: south
# next pos: [-2, 4, -99]
# Random action: west
# next pos: [-2, 4, -100]
# Random action: west
# next pos: [-2, 4, -101]
# Random action: west
# next pos: [-2, 4, -102]
# Random action: west
# next pos: [-1, 4, -104]
# Random action: north
# next pos: [-1, 4, -103]
# Random action: south
# next pos: [-1, 4, -106]
# Random action: north
# next pos: [0, 4, -106]
# Random action: east
# next pos: [0, 4, -107]
# Random action: east
# next pos: [-1, 4, -109]
# Random action: north
# next pos: [-1, 4, -110]
# Random action: north
# next pos: [-2, 4, -110]
# Random action: west
# next pos: [0, 4, -111]
# Random action: east
# next pos: [-2, 4, -112]
# Random action: west
# next pos: [-1, 4, -114]
# Random action: north
# next pos: [-1, 4, -113]
# Random action: south
# next pos: [-2, 4, -115]
# Random action: west
# next pos: [-2, 4, -116]
# Random action: west
# next pos: [-1, 4, -118]
# Random action: north
# next pos: [0, 4, -118]
# Random action: east
# next pos: [-1, 4, -118]
# Random action: south
# next pos: [-2, 4, -120]
# Random action: west
# next pos: [-2, 4, -121]
# Random action: west
# next pos: [-1, 4, -123]
# Random action: north
# next pos: [-2, 4, -123]
# Random action: west
# next pos: [-1, 4, -123]
# Random action: south
# next pos: [-2, 4, -125]
# Random action: west
# next pos: [-1, 4, -125]
# Random action: south
# next pos: [-1, 4, -128]
# Random action: north
# next pos: [-2, 4, -128]
# Random action: west
# next pos: [0, 4, -129]
# Random action: east
# next pos: [0, 4, -130]
# Random action: east
# next pos: [-2, 4, -131]
# Random action: west
# next pos: [0, 4, -132]
# Random action: east
# next pos: [0, 4, -133]
# Random action: east
# next pos: [0, 4, -134]
# Random action: east
# next pos: [-1, 4, -136]
# Random action: north
# next pos: [-1, 4, -137]
# Random action: north
# next pos: [-2, 4, -137]
# Random action: west
# next pos: [-1, 4, -139]
# Random action: north
# next pos: [-1, 4, -138]
# Random action: south
# next pos: [-1, 4, -139]
# Random action: south
# next pos: [-2, 4, -141]
# Random action: west
# next pos: [-2, 4, -142]
# Random action: west
# next pos: [-2, 4, -143]
# Random action: west
# next pos: [-2, 4, -144]
# Random action: west
# next pos: [-1, 4, -146]
# Random action: north
# next pos: [-2, 4, -146]
# Random action: west
# next pos: [-1, 4, -146]
# Random action: south
# next pos: [-1, 4, -146]
# Random action: south
# next pos: [-2, 4, -149]
# Random action: west
# next pos: [-1, 4, -149]
# Random action: south
# next pos: [-1, 4, -151]
# Random action: north
# next pos: [0, 4, -152]
# Random action: east
# next pos: [-2, 4, -152]
# Random action: west
# next pos: [-1, 4, -152]
# Random action: south
# next pos: [-2, 4, -154]
# Random action: west
# next pos: [-1, 4, -155]
# Random action: south
# next pos: [-1, 4, -158]
# Random action: north
# next pos: [0, 4, -158]
# Random action: east
# next pos: [0, 4, -158]
# Random action: east
# next pos: [-1, 4, -161]
# Random action: north
# next pos: [-1, 4, -160]
# Random action: south
# next pos: [-2, 4, -162]
# Random action: west
# next pos: [-1, 4, -164]
# Random action: north
# next pos: [-1, 4, -163]
# Random action: south
# next pos: [-2, 4, -165]
# Random action: west
# next pos: [-1, 4, -167]
# Random action: north
# next pos: [-2, 4, -167]
# Random action: west
# next pos: [-1, 4, -169]
# Random action: north
# next pos: [-2, 4, -169]
# Random action: west
# next pos: [0, 4, -170]
# Random action: east
# next pos: [0, 4, -171]
# Random action: east
# next pos: [0, 4, -172]
# Random action: east
# next pos: [0, 4, -173]
# Random action: east
# next pos: [-1, 4, -175]
# Random action: north
# next pos: [0, 4, -175]
# Random action: east
# next pos: [-2, 4, -176]
# Random action: west
# next pos: [-1, 4, -178]
# Random action: north
# next pos: [-1, 4, -177]
# Random action: south
# next pos: [0, 4, -179]
# Random action: east
# next pos: [0, 4, -180]
# Random action: east
# next pos: [-1, 4, -180]
# Random action: south
# next pos: [0, 4, -182]
# Random action: east
# next pos: [-1, 4, -182]
# Random action: south
# next pos: [-1, 4, -183]
# Random action: south
# next pos: [-2, 4, -185]
# Random action: west
# next pos: [-1, 4, -185]
# Random action: south
# next pos: [-1, 4, -188]
# Random action: north
# next pos: [0, 4, -188]
# Random action: east
# next pos: [0, 4, -189]
# Random action: east
# next pos: [-1, 4, -191]
# Random action: north
# next pos: [-2, 4, -191]
# Random action: west
# next pos: [-1, 4, -193]
# Random action: north
# next pos: [-1, 4, -192]
# Random action: south
# next pos: [-2, 4, -194]
# Random action: west
# next pos: [-1, 4, -194]
# Random action: south
# next pos: [0, 4, -196]
# Random action: east
# next pos: [-2, 4, -196]
# Random action: west
# next pos: [0, 4, -198]
# Random action: east
# next pos: [0, 4, -199]
# Random action: east
# next pos: [0, 4, -200]
# Random action: east
# next pos: [-1, 4, -202]
# Random action: north
# next pos: [-2, 4, -202]
# Random action: west
# next pos: [-2, 4, -203]
# Random action: west
# next pos: [-1, 4, -205]
# Random action: north
# next pos: [0, 4, -205]
# Random action: east
# next pos: [-1, 4, -207]
# Random action: north
# next pos: [-1, 4, -208]
# Random action: north
# next pos: [-1, 4, -207]
# Random action: south
# next pos: [-2, 4, -209]
# Random action: west
# next pos: [-2, 4, -210]
# Random action: west
# next pos: [-2, 4, -211]
# Random action: west
# next pos: [-2, 4, -212]
# Random action: west
# next pos: [0, 4, -213]
# Random action: east
# next pos: [-1, 4, -213]
# Random action: south
# next pos: [-2, 4, -215]
# Random action: west
# next pos: [0, 4, -216]
# Random action: east
# next pos: [-2, 4, -217]
# Random action: west
# next pos: [-1, 4, -217]
# Random action: south
# next pos: [-1, 4, -220]
# Random action: north
# next pos: [0, 4, -220]
# Random action: east
# next pos: [-1, 4, -220]
# Random action: south
# next pos: [0, 4, -222]
# Random action: east
# next pos: [0, 4, -223]
# Random action: east
# next pos: [0, 4, -224]
# Random action: east
# next pos: [-1, 4, -224]
# Random action: south
# next pos: [-1, 4, -225]
# Random action: south
# next pos: [-1, 4, -228]
# Random action: north
# next pos: [-2, 4, -228]
# Random action: west
# next pos: [0, 4, -229]
# Random action: east
# next pos: [-1, 4, -231]
# Random action: north
# next pos: [-1, 4, -230]
# Random action: south
# next pos: [-1, 4, -231]
# Random action: south
# next pos: [-1, 4, -232]
# Random action: south
# next pos: [-1, 4, -233]
# Random action: south
# next pos: [0, 4, -235]
# Random action: east
# next pos: [-2, 4, -236]
# Random action: west
# next pos: [-2, 4, -237]
# Random action: west
# next pos: [-1, 4, -239]
# Random action: north
# next pos: [-2, 4, -239]
# Random action: west
# next pos: [-2, 4, -240]
# Random action: west
# next pos: [-1, 4, -242]
# Random action: north
# next pos: [-2, 4, -242]
# Random action: west
# next pos: [0, 4, -243]
# Random action: east
# next pos: [-1, 4, -243]
# Random action: south
# next pos: [0, 4, -245]
# Random action: east
# next pos: [-1, 4, -247]
# Random action: north
# next pos: [-1, 4, -248]
# Random action: north
# next pos: [-1, 4, -247]
# Random action: south
# next pos: [-1, 4, -250]
# Random action: north
# next pos: [-1, 4, -249]
# Random action: south
# next pos: [0, 4, -251]
# Random action: east
# next pos: [-1, 4, -251]
# Random action: south
# next pos: [-1, 4, -252]
# Random action: south
# next pos: [0, 4, -254]
# Random action: east
# next pos: [0, 4, -255]
# Random action: east
# next pos: [0, 4, -256]
# Random action: east
# next pos: [-1, 4, -256]
# Random action: south
# next pos: [0, 4, -258]
# Random action: east
# next pos: [-1, 4, -260]
# Random action: north
# next pos: [-1, 4, -261]
# Random action: north
# next pos: [-1, 4, -260]
# Random action: south
# next pos: [-1, 4, -261]
# Random action: south
# next pos: [0, 4, -263]
# Random action: east
# next pos: [0, 4, -264]
# Random action: east
# next pos: [-1, 4, -264]
# Random action: south
# next pos: [-1, 4, -265]
# Random action: south
# next pos: [-2, 4, -267]
# Random action: west
# next pos: [-1, 4, -269]
# Random action: north
# next pos: [0, 4, -269]
# Random action: east
# next pos: [-2, 4, -270]
# Random action: west
# next pos: [0, 4, -271]
# Random action: east
# next pos: [-1, 4, -273]
# Random action: north
# next pos: [-1, 4, -274]
# Random action: north
# next pos: [-1, 4, -273]
# Random action: south
# next pos: [0, 4, -275]
# Random action: east
# next pos: [-1, 4, -277]
# Random action: north
# next pos: [-2, 4, -277]
# Random action: west
# next pos: [-2, 4, -278]
# Random action: west
# next pos: [0, 4, -279]
# Random action: east
# next pos: [0, 4, -280]
# Random action: east
# next pos: [0, 4, -281]
# Random action: east
# next pos: [-1, 4, -281]
# Random action: south
# next pos: [-1, 4, -284]
# Random action: north
# next pos: [-1, 4, -283]
# Random action: south
# next pos: [0, 4, -285]
# Random action: east
# next pos: [-1, 4, -285]
# Random action: south
# next pos: [-1, 4, -286]
# Random action: south
# next pos: [-1, 4, -289]
# Random action: north
# next pos: [-1, 4, -290]
# Random action: north
# next pos: [-1, 4, -289]
# Random action: south
# next pos: [-1, 4, -290]
# Random action: south
# next pos: [-2, 4, -292]
# Random action: west
# next pos: [0, 4, -293]
# Random action: east
# next pos: [-1, 4, -293]
# Random action: south
# next pos: [-2, 4, -295]
# Random action: west
# next pos: [0, 4, -296]
# Random action: east
# next pos: [0, 4, -297]
# Random action: east
# next pos: [-2, 4, -298]
# Random action: west
# next pos: [-2, 4, -299]
# Random action: west
# next pos: [-1, 4, -301]
# Random action: north
# next pos: [-1, 4, -300]
# Random action: south
# next pos: [-1, 4, -303]
# Random action: north
# next pos: [0, 4, -303]
# Random action: east
# next pos: [-2, 4, -304]
# Random action: west
# next pos: [0, 4, -305]
# Random action: east
# next pos: [0, 4, -306]
# Random action: east
# next pos: [-2, 4, -307]
# Random action: west
# next pos: [0, 4, -308]
# Random action: east
# next pos: [-2, 4, -309]
# Random action: west
# next pos: [0, 4, -310]
# Random action: east
# next pos: [-1, 4, -310]
# Random action: south
# next pos: [0, 4, -312]
# Random action: east
# next pos: [0, 4, -313]
# Random action: east
# next pos: [-2, 4, -314]
# Random action: west
# next pos: [-2, 4, -315]
# Random action: west
# next pos: [-1, 4, -315]
# Random action: south
# next pos: [0, 4, -317]
# Random action: east
# next pos: [0, 4, -318]
# Random action: east
# next pos: [-1, 4, -318]
# Random action: south
# next pos: [-1, 4, -319]
# Random action: south
# next pos: [-2, 4, -321]
# Random action: west
# next pos: [-1, 4, -323]
# Random action: north
# next pos: [0, 4, -323]
# Random action: east
# next pos: [-1, 4, -325]
# Random action: north
# next pos: [-2, 4, -325]
# Random action: west
# next pos: [-1, 4, -325]
# Random action: south
# next pos: [0, 4, -327]
# Random action: east
# next pos: [-1, 4, -329]
# Random action: north
# next pos: [0, 4, -329]
# Random action: east
# next pos: [-2, 4, -330]
# Random action: west
# next pos: [-1, 4, -330]
# Random action: south
# next pos: [-2, 4, -332]
# Random action: west
# next pos: [-1, 4, -332]
# Random action: south
# next pos: [-2, 4, -334]
# Random action: west
# next pos: [0, 4, -335]
# Random action: east
# next pos: [0, 4, -336]
# Random action: east
# next pos: [0, 4, -337]
# Random action: east
# next pos: [0, 4, -338]
# Random action: east
# next pos: [-1, 4, -340]
# Random action: north
# next pos: [0, 4, -340]
# Random action: east
# next pos: [0, 4, -341]
# Random action: east
# next pos: [0, 4, -342]
# Random action: east
# next pos: [-2, 4, -343]
# Random action: west
# next pos: [-1, 4, -345]
# Random action: north
# next pos: [-1, 4, -346]
# Random action: north
# next pos: [0, 4, -346]
# Random action: east
# next pos: [-1, 4, -346]
# Random action: south
# next pos: [-1, 4, -349]
# Random action: north
# next pos: [-1, 4, -348]
# Random action: south
# next pos: [-2, 4, -350]
# Random action: west
# next pos: [0, 4, -351]
# Random action: east
# next pos: [0, 4, -352]
# Random action: east
# next pos: [-1, 4, -354]
# Random action: north
# next pos: [0, 4, -354]
# Random action: east
# next pos: [-1, 4, -354]
# Random action: south
# next pos: [-2, 4, -356]
# Random action: west
# next pos: [0, 4, -357]
# Random action: east
# next pos: [-2, 4, -358]
# Random action: west
# next pos: [0, 4, -359]
# Random action: east
# next pos: [-2, 4, -360]
# Random action: west
# next pos: [-1, 4, -362]
# Random action: north
# next pos: [-2, 4, -362]
# Random action: west
# next pos: [-1, 4, -362]
# Random action: south
# next pos: [-2, 4, -364]
# Random action: west
# next pos: [-1, 4, -364]
# Random action: south
# next pos: [-2, 4, -366]
# Random action: west
# next pos: [0, 4, -367]
# Random action: east
# next pos: [-1, 4, -367]
# Random action: south
# next pos: [-1, 4, -370]
# Random action: north
# next pos: [-1, 4, -369]
# Random action: south
# next pos: [0, 4, -371]
# Random action: east
# next pos: [-1, 4, -371]
# Random action: south
# next pos: [-2, 4, -373]
# Random action: west
# next pos: [-2, 4, -374]
# Random action: west
# next pos: [0, 4, -375]
# Random action: east
# next pos: [-1, 4, -375]
# Random action: south
# next pos: [-1, 4, -376]
# Random action: south
# next pos: [-1, 4, -379]
# Random action: north
# next pos: [-2, 4, -379]
# Random action: west
# next pos: [-2, 4, -380]
# Random action: west
# next pos: [-2, 4, -381]
# Random action: west
# next pos: [-1, 4, -381]
# Random action: south
# next pos: [-2, 4, -383]
# Random action: west
# next pos: [0, 4, -384]
# Random action: east
# next pos: [0, 4, -385]
# Random action: east
# next pos: [-2, 4, -386]
# Random action: west
# next pos: [-1, 4, -386]
# Random action: south
# next pos: [0, 4, -388]
# Random action: east
# next pos: [-1, 4, -390]
# Random action: north
# next pos: [0, 4, -390]
# Random action: east
# next pos: [-2, 4, -391]
# Random action: west
# next pos: [0, 4, -392]
# Random action: east
# next pos: [-2, 4, -393]
# Random action: west
# next pos: [0, 4, -394]
# Random action: east
# next pos: [-2, 4, -395]
# Random action: west
# next pos: [-1, 4, -397]
# Random action: north
# next pos: [-1, 4, -398]
# Random action: north
# next pos: [-2, 4, -398]
# Random action: west
# next pos: [0, 4, -399]
# Random action: east
# next pos: [-1, 4, -401]
# Random action: north
# next pos: [0, 4, -401]
# Random action: east
# next pos: [-1, 4, -401]
# Random action: south
# next pos: [-1, 4, -402]
# Random action: south
# next pos: [0, 4, -404]
# Random action: east
# next pos: [-2, 4, -405]
# Random action: west
# next pos: [-2, 4, -406]
# Random action: west
# next pos: [-1, 4, -408]
# Random action: north
# next pos: [-1, 4, -407]
# Random action: south
# next pos: [-1, 4, -408]
# Random action: south
# next pos: [-2, 4, -410]
# Random action: west
# next pos: [-1, 4, -410]
# Random action: south
# next pos: [0, 4, -412]
# Random action: east
# next pos: [-1, 4, -412]
# Random action: south
# next pos: [-1, 4, -413]
# Random action: south
# next pos: [-1, 4, -416]
# Random action: north
# next pos: [-1, 4, -415]
# Random action: south
# next pos: [-1, 4, -416]
# Random action: south
# next pos: [0, 4, -418]
# Random action: east
# next pos: [0, 4, -419]
# Random action: east
# next pos: [0, 4, -420]
# Random action: east
# next pos: [-1, 4, -422]
# Random action: north
# next pos: [-1, 4, -421]
# Random action: south
# next pos: [-1, 4, -422]
# Random action: south
# next pos: [0, 4, -424]
# Random action: east
# next pos: [-2, 4, -425]
# Random action: west
# next pos: [0, 4, -426]
# Random action: east
# next pos: [0, 4, -427]
# Random action: east
# next pos: [-1, 4, -427]
# Random action: south
# next pos: [0, 4, -429]
# Random action: east
# next pos: [-1, 4, -429]
# Random action: south
# next pos: [0, 4, -431]
# Random action: east
# next pos: [-1, 4, -431]
# Random action: south
# next pos: [-2, 4, -433]
# Random action: west
# next pos: [-1, 4, -435]
# Random action: north
# next pos: [0, 4, -435]
# Random action: east
# next pos: [-1, 4, -435]
# Random action: south
# next pos: [0, 4, -437]
# Random action: east
# next pos: [-1, 4, -437]
# Random action: south
# next pos: [-2, 4, -439]
# Random action: west
# next pos: [0, 4, -440]
# Random action: east
# next pos: [-1, 4, -440]
# Random action: south
# next pos: [-1, 4, -443]
# Random action: north
# next pos: [-1, 4, -442]
# Random action: south
# next pos: [-1, 4, -445]
# Random action: north
# next pos: [-1, 4, -444]
# Random action: south
# next pos: [-1, 4, -447]
# Random action: north
# next pos: [-1, 4, -446]
# Random action: south
# next pos: [-2, 4, -448]
# Random action: west
# next pos: [-1, 4, -450]
# Random action: north
# next pos: [-1, 4, -451]
# Random action: north
# next pos: [-1, 4, -452]
# Random action: north
# next pos: [-2, 4, -452]
# Random action: west
# next pos: [-1, 4, -452]
# Random action: south
# next pos: [-2, 4, -454]
# Random action: west
# next pos: [0, 4, -455]
# Random action: east
# next pos: [-2, 4, -456]
# Random action: west
# next pos: [-1, 4, -456]
# Random action: south
# next pos: [0, 4, -458]
# Random action: east
# next pos: [-1, 4, -460]
# Random action: north
# next pos: [-1, 4, -461]
# Random action: north
# next pos: [-2, 4, -461]
# Random action: west
# next pos: [-1, 4, -461]
# Random action: south
# next pos: [0, 4, -463]
# Random action: east
# next pos: [-2, 4, -464]
# Random action: west
# next pos: [-2, 4, -464]
# Random action: west
# next pos: [-1, 4, -467]
# Random action: north
# next pos: [0, 4, -467]
# Random action: east
# next pos: [-1, 4, -469]
# Random action: north
# next pos: [-1, 4, -470]
# Random action: north
# next pos: [-1, 4, -469]
# Random action: south
# next pos: [-2, 4, -471]
# Random action: west
# next pos: [0, 4, -472]
# Random action: east
# next pos: [-1, 4, -472]
# Random action: south
# next pos: [-2, 4, -474]
# Random action: west
# next pos: [0, 4, -475]
# Random action: east
# next pos: [-1, 4, -475]
# Random action: south
# Cumulative reward: -478
